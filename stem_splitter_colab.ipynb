# %% [markdown]
# # Free Stem Splitter + Tempo/Key Finder (Colab)
# Upload **app.py** and your song, then run the cells below.

# %%
# !pip -q install demucs librosa numpy soundfile

# %%
from google.colab import files
uploaded = files.upload()  # upload app.py + your song

# %%
# !ls -la

# %%
# If your filename is long or has spaces, rename it first. Example:
# !mv "your song name.mp3" song.mp3

# !python app.py "song.mp3" --out outputs --format wav

# %%
import shutil
from google.colab import files

shutil.make_archive("stems", "zip", "outputs")
files.download("stems.zip")
